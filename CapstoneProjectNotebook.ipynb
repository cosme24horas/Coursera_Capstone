# %% [markdown]
# # Applied Data Science Capstone - Capstone Project

# %% [markdown]
# The final capstone project is about use locations data and machine learning to solve a problem. The problem is make decision about to accept a new job in other and distant neighborhood, based on characteristics between the actual neighborhood and the possibles new neighborhoods, using locations data and machine learning.

# %% [markdown]
# # by Cosme Silveira

# %%
import numpy as np
import pandas as pd

# %%
print("Hello Capstone Project Course!")
# Out:
# Hello Capstone Project Course!
